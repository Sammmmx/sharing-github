# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sammy'

# %%
#We will be doing some Advanced Visualizations using Seaborn and Matplotlib

# %%
#Importing the data.

# %%
os.chdir('C:\\Users\\sammy\\Documents\\Python Programming')

# %%
MovieRatings = pd.read_csv('P4-Movie-Ratings.csv')

# %%
MovieRatings
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
#Renaming the Variables and columns.

# %%
MR = MovieRatings

# %%
MR.columns = ['Film', 'Genre', 'RTR', 'AudienceRatings', 'Budget', 'YearofRelease']

# %%
#Getting to know your data.

# %%
MR
# Out:
#                       Film      Genre  RTR  AudienceRatings  Budget  \
# 0    (500) Days of Summer      Comedy   87               81       8
# 1              10,000 B.C.  Adventure    9               44     105
# 2               12 Rounds      Action   30               52      20
# 3                127 Hours  Adventure   93               84      18
# 4                17 Again      Comedy   55               70      20
# ..                     ...        ...  ...              ...     ...
# 554          Your Highness     Comedy   26               36      50
# 555        Youth in Revolt     Comedy   68               52      18
# 556                 Zodiac   Thriller   89               73      65
# 557            Zombieland      Action   90               87      24
# 558              Zookeeper     Comedy   14               42      80
#
#      YearofRelease
# 0             2009
# 1             2008
# 2             2009
# 3             2010
# 4             2009
# ..             ...
# ...

# %%
MR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   RTR              559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   YearofRelease    559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
MR.describe()
# Out:
#               RTR  AudienceRatings      Budget  YearofRelease
# count  559.000000       559.000000  559.000000     559.000000
# mean    47.309481        58.744186   50.236136    2009.152057
# std     26.413091        16.826887   48.731817       1.362632
# min      0.000000         0.000000    0.000000    2007.000000
# 25%     25.000000        47.000000   20.000000    2008.000000
# 50%     46.000000        58.000000   35.000000    2009.000000
# 75%     70.000000        72.000000   65.000000    2010.000000
# max     97.000000        96.000000  300.000000    2011.000000

# %%
#Some basic Visualizations

# %%
MR[['RTR', 'AudienceRatings']]
# Out:
#      RTR  AudienceRatings
# 0     87               81
# 1      9               44
# 2     30               52
# 3     93               84
# 4     55               70
# ..   ...              ...
# 554   26               36
# 555   68               52
# 556   89               73
# 557   90               87
# 558   14               42
#
# [559 rows x 2 columns]

# %%
MR[['RTR', 'Budget']]
# Out:
#      RTR  Budget
# 0     87       8
# 1      9     105
# 2     30      20
# 3     93      18
# 4     55      20
# ..   ...     ...
# 554   26      50
# 555   68      18
# 556   89      65
# 557   90      24
# 558   14      80
#
# [559 rows x 2 columns]

# %%
MR
# Out:
#                       Film      Genre  RTR  AudienceRatings  Budget  \
# 0    (500) Days of Summer      Comedy   87               81       8
# 1              10,000 B.C.  Adventure    9               44     105
# 2               12 Rounds      Action   30               52      20
# 3                127 Hours  Adventure   93               84      18
# 4                17 Again      Comedy   55               70      20
# ..                     ...        ...  ...              ...     ...
# 554          Your Highness     Comedy   26               36      50
# 555        Youth in Revolt     Comedy   68               52      18
# 556                 Zodiac   Thriller   89               73      65
# 557            Zombieland      Action   90               87      24
# 558              Zookeeper     Comedy   14               42      80
#
#      YearofRelease
# 0             2009
# 1             2008
# 2             2009
# 3             2010
# 4             2009
# ..             ...
# ...

# %%
MR.Film = MR.Film.astype('category')

# %%
MR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   RTR              559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   YearofRelease    559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
MR.Genre.unique()
# Out:
# array(['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance',
#        'Thriller'], dtype=object)

# %%
MR.Genre = MR.Genre.astype('category')

# %%
MR.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
MR.YearofRelease = MR.YearofRelease.astype('category')

# %%
MR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   RTR              559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   YearofRelease    559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
#Starting with Plots and Histograms

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sea

# %%
# %matplotlib inline

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
MR
# Out:
#                       Film      Genre  RTR  AudienceRatings  Budget  \
# 0    (500) Days of Summer      Comedy   87               81       8
# 1              10,000 B.C.  Adventure    9               44     105
# 2               12 Rounds      Action   30               52      20
# 3                127 Hours  Adventure   93               84      18
# 4                17 Again      Comedy   55               70      20
# ..                     ...        ...  ...              ...     ...
# 554          Your Highness     Comedy   26               36      50
# 555        Youth in Revolt     Comedy   68               52      18
# 556                 Zodiac   Thriller   89               73      65
# 557            Zombieland      Action   90               87      24
# 558              Zookeeper     Comedy   14               42      80
#
#     YearofRelease
# 0            2009
# 1            2008
# 2            2009
# 3            2010
# 4            2009
# ..            ...
# ...

# %%
MRjoint = sea.jointplot(data=MR, x='RTR', y='AudienceRatings')

# %%
MR.columns
# Out:
# Index(['Film', 'Genre', 'RTR', 'AudienceRatings', 'Budget', 'YearofRelease'], dtype='object')

# %%
MRjoint = sea.jointplot(data=MR, x='RTR', y='AudienceRatings', kind='hex')

# %%
MRjoint = sea.jointplot(data=MR, x='RTR', y='AudienceRatings', kind='hist')

# %%
MR1 = sea.distplot(MR.AudienceRatings, bins=15)

# %%
sea.set_style('white')
MR1 = plt.hist(MR.AudienceRatings)

# %%
MR1 = sea.distplot(MR.RTR)

# %%
H1 = plt.hist(MR.Budget)

# %%
MR[MR.YearofRelease == 2010]
# Out:
#                                    Film      Genre  RTR  AudienceRatings  \
# 3                             127 Hours  Adventure   93               84
# 12            A Nightmare on Elm Street     Horror   13               40
# 19                  Alice in Wonderland  Adventure   52               72
# 23                      All Good Things      Drama   33               64
# 44                            Beginners     Comedy   84               80
# ..                                  ...        ...  ...              ...
# 543          Why Did I Get Married Too?     Comedy   27               67
# 545                       Winter's Bone      Drama   94               73
# 550                           Yogi Bear     Comedy   14               36
# 551                           You Again     Comedy   18               45
# 553  You Will Meet a Tall Dark Stranger     Comedy   43               35
#
#      Budget YearofRelease
# 3        18          2010
# 12       35          2010
# ...

# %%
H1 = plt.hist(MR[MR.YearofRelease == 2010].Budget)

# %%
vis1 = MR[MR.YearofRelease == 2010]

# %%
vis1
# Out:
#                                    Film      Genre  RTR  AudienceRatings  \
# 3                             127 Hours  Adventure   93               84
# 12            A Nightmare on Elm Street     Horror   13               40
# 19                  Alice in Wonderland  Adventure   52               72
# 23                      All Good Things      Drama   33               64
# 44                            Beginners     Comedy   84               80
# ..                                  ...        ...  ...              ...
# 543          Why Did I Get Married Too?     Comedy   27               67
# 545                       Winter's Bone      Drama   94               73
# 550                           Yogi Bear     Comedy   14               36
# 551                           You Again     Comedy   18               45
# 553  You Will Meet a Tall Dark Stranger     Comedy   43               35
#
#      Budget YearofRelease
# 3        18          2010
# 12       35          2010
# ...

# %%
H1 = plt.hist([MR[MR.Genre == 'Drama'].Budget, MR[MR.Genre == 'Action'].Budget, MR[MR.Genre == 'Comedy'].Budget], stacked=True)
plt.legend('upper right')

# %%
list1 = list()
MyLabels = list()
for gen in MR.Genre.cat.categories:
    list1.append(MR[MR.Genre == gen].Budget)
    MyLabels.append(gen)
plt.hist(list1, bins=30, stacked=True, rwidth=1, label=MyLabels)
plt.legend()
plt.show()
plt.rcParams['figure.figsize'] = 20,15
sea.set_style = 'white'

# %%
#Time for Seaborn

# %%
MR
# Out:
#                       Film      Genre  RTR  AudienceRatings  Budget  \
# 0    (500) Days of Summer      Comedy   87               81       8
# 1              10,000 B.C.  Adventure    9               44     105
# 2               12 Rounds      Action   30               52      20
# 3                127 Hours  Adventure   93               84      18
# 4                17 Again      Comedy   55               70      20
# ..                     ...        ...  ...              ...     ...
# 554          Your Highness     Comedy   26               36      50
# 555        Youth in Revolt     Comedy   68               52      18
# 556                 Zodiac   Thriller   89               73      65
# 557            Zombieland      Action   90               87      24
# 558              Zookeeper     Comedy   14               42      80
#
#     YearofRelease
# 0            2009
# 1            2008
# 2            2009
# 3            2010
# 4            2009
# ..            ...
# ...

# %%
vis99 = sea.lmplot(data=MR, x='RTR', y='AudienceRatings', fit_reg=False, size=5, palette='')

# %%
k1 = sea.kdeplot(MR.AudienceRatings, MR.RTR, size=5)

# %%
k1 = sea.kdeplot(MR.AudienceRatings, MR.RTR, shade=True, shade_lowest=False, cmap='Reds')

# %%
K2 = sea.kdeplot(MR.Budget, MR.RTR, shade=True, shade_lowest=False, cmap='Reds')

# %%
K3 = sea.kdeplot(MR.Budget, MR.AudienceRatings, shade=True, shade_lowest=False, cmap='Blues')

# %%
f, axes = plt.subplots(1, 2, figsize=(16,8))

K2 = sea.kdeplot(MR.Budget, MR.RTR, ax=axes[0])

K3 = sea.kdeplot(MR.Budget, MR.AudienceRatings, ax=axes[1])

K3.set(xlim=(-20,160))
# Out:
# [(-20.0, 160.0)]

# %%
f, axes = plt.subplots(2, 2, figsize=(12,6))

K2 = sea.kdeplot(MR.Budget, MR.RTR, ax=axes[0,1])

#K3 = sea.kdeplot(MR.Budget, MR.AudienceRatings, ax=axes[1])

# %%
VP = sea.violinplot(data=MR[MR.Genre == 'Drama'], x='YearofRelease', y='RTR')

# %%
FG = sea.FacetGrid(MR, row='Genre', col='YearofRelease', hue='Genre')

# %%
FG = sea.FacetGrid(MR, row='Genre', col='YearofRelease', hue='Genre')

FG = FG.map(plt.scatter, 'RTR', 'AudienceRatings')

# %%
FG = sea.FacetGrid(MR, row='Genre', col='YearofRelease', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='Black')
FG = FG.map(plt.scatter, 'RTR', 'AudienceRatings', **kws)
FG.set(xlim=(0,100), ylim=(0,100))

# %%
FG = sea.FacetGrid(MR, row='Genre', col='YearofRelease', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='Black')
FG = FG.map(plt.scatter, 'RTR', 'AudienceRatings', **kws)
FG.set(xlim=(0,100), ylim=(0,100))
#add lines to each of these graphs using loop
for ax in FG.axes.flat:
    ax.plot((0,100), (0,100), c='Red', ls='-.')
FG.add_legend()
