# %%
#Methods to import data into python

# %%
import pandas as pd

# %%
# 1. Specify Full Path to File

# %%
Data = pd.read_csv('C:\\Users\\sammy\\Documents\\Python Programming\\P4-Demographic-Data.csv')

# %%
Data
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\sammy\Documents\Python Programming

# %%
os.chdir('C:\\Users\\sammy\\Documents\\Python Programming')

# %%
print(os.getcwd())
# Out:
# C:\Users\sammy\Documents\Python Programming

# %%
Data2 = pd.read_csv('P4-Demographic-Data.csv')

# %%
Data2
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
len(Data)
# Out:
# 195

# %%
Data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#Number of coulmns
len(Data.columns)
# Out:
# 5

# %%
Data
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
Data
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
Data[50:61]
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 50                Ecuador          ECU      21.070       40.353684
# 51       Egypt, Arab Rep.          EGY      28.032       29.400000
# 52                Eritrea          ERI      34.800        0.900000
# 53                  Spain          ESP       9.100       71.635000
# 54                Estonia          EST      10.300       79.400000
# 55               Ethiopia          ETH      32.925        1.900000
# 56                Finland          FIN      10.700       91.514400
# 57                   Fiji          FJI      20.463       37.100000
# 58                 France          FRA      12.300       81.919800
# 59  Micronesia, Fed. Sts.          FSM      23.511       27.800000
# 60                  Gabon          GAB      30.555        9.200000
#
#            Income Group
# 50  Upper middle income
# 51  Lower middle income
# 52           Low income
# 53          High income
# 54          High income
# ...

# %%
Data[70:81]
# Out:
#             Country Name Country Code  Birth rate  Internet users  \
# 70             Greenland          GRL      14.500         65.8000
# 71             Guatemala          GTM      27.465         19.7000
# 72                  Guam          GUM      17.389         65.4000
# 73                Guyana          GUY      18.885         35.0000
# 74  Hong Kong SAR, China          HKG       7.900         74.2000
# 75              Honduras          HND      21.593         17.8000
# 76               Croatia          HRV       9.400         66.7476
# 77                 Haiti          HTI      25.345         10.6000
# 78               Hungary          HUN       9.200         72.6439
# 79             Indonesia          IDN      20.297         14.9400
# 80                 India          IND      20.291         15.1000
#
#            Income Group
# 70          High income
# 71  Lower middle income
# 72          High income
# 73  Lower middle income
# 74          High income
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
Data[-194:-1]
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# 5               Argentina          ARG      17.716            59.9
# ..                    ...          ...         ...             ...
# 189                 Samoa          WSM      26.172            15.3
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
#
#             Income Group
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# 5            High income
# ...

# %%
Data.reorder_levels
# Out:
# <bound method DataFrame.reorder_levels of              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# ...

# %%
Data
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
Data[0:20:5]
# Out:
#    Country Name Country Code  Birth rate  Internet users         Income Group
# 0         Aruba          ABW      10.244           78.90          High income
# 5     Argentina          ARG      17.716           59.90          High income
# 10   Azerbaijan          AZE      18.300           58.70  Upper middle income
# 15   Bangladesh          BGD      20.142            6.63  Lower middle income

# %%
Data[ : :-1]
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 194              Zimbabwe          ZWE      35.715            18.5
# 193                Zambia          ZMB      40.471            15.4
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 191          South Africa          ZAF      20.850            46.5
# 190           Yemen, Rep.          YEM      32.947            20.0
# ..                    ...          ...         ...             ...
# 4    United Arab Emirates          ARE      11.044            88.0
# 3                 Albania          ALB      12.877            57.2
# 2                  Angola          AGO      45.985            19.1
# 1             Afghanistan          AFG      35.253             5.9
# 0                   Aruba          ABW      10.244            78.9
#
#             Income Group
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ...

# %%
Data[ : :20]
# Out:
#     Country Name Country Code  Birth rate  Internet users         Income Group
# 0          Aruba          ABW      10.244         78.9000          High income
# 20       Belarus          BLR      12.500         54.1700  Upper middle income
# 40    Costa Rica          CRI      15.022         45.9600  Upper middle income
# 60         Gabon          GAB      30.555          9.2000  Upper middle income
# 80         India          IND      20.291         15.1000  Lower middle income
# 100        Libya          LBY      21.425         16.5000  Upper middle income
# 120   Mozambique          MOZ      39.705          5.4000           Low income
# 140       Poland          POL       9.600         62.8492          High income
# 160     Suriname          SUR      18.455         37.4000  Upper middle income
# 180      Uruguay          URY      14.374         57.6900          High income

# %%
Data.columns[1]
# Out:
# 'Country Code'

# %%
Data[Data.columns[1]]
# Out:
# 0      ABW
# 1      AFG
# 2      AGO
# 3      ALB
# 4      ARE
#       ...
# 190    YEM
# 191    ZAF
# 192    COD
# 193    ZMB
# 194    ZWE
# Name: Country Code, Length: 195, dtype: object

# %%
Data[Data.columns[0]]
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: Country Name, Length: 195, dtype: object

# %%
Data['Income Group']
# Out:
# 0              High income
# 1               Low income
# 2      Upper middle income
# 3      Upper middle income
# 4              High income
#               ...
# 190    Lower middle income
# 191    Upper middle income
# 192             Low income
# 193    Lower middle income
# 194             Low income
# Name: Income Group, Length: 195, dtype: object

# %%
Data[Data.columns[1:2]]
# Out:
#     Country Code
# 0            ABW
# 1            AFG
# 2            AGO
# 3            ALB
# 4            ARE
# ..           ...
# 190          YEM
# 191          ZAF
# 192          COD
# 193          ZMB
# 194          ZWE
#
# [195 rows x 1 columns]

# %%
Data['Birth rate']
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: Birth rate, Length: 195, dtype: float64

# %%
Data[['Birth rate', 'Income Group']]
#you need double brackets to print to specific columns at the same time.
# Out:
#      Birth rate         Income Group
# 0        10.244          High income
# 1        35.253           Low income
# 2        45.985  Upper middle income
# 3        12.877  Upper middle income
# 4        11.044          High income
# ..          ...                  ...
# 190      32.947  Lower middle income
# 191      20.850  Upper middle income
# 192      42.394           Low income
# 193      40.471  Lower middle income
# 194      35.715           Low income
#
# [195 rows x 2 columns]

# %%
Data[['Birth rate', 'Income Group']][69:88]
# Out:
#     Birth rate         Income Group
# 69      19.334  Upper middle income
# 70      14.500          High income
# 71      27.465  Lower middle income
# 72      17.389          High income
# 73      18.885  Lower middle income
# 74       7.900          High income
# 75      21.593  Lower middle income
# 76       9.400          High income
# 77      25.345           Low income
# 78       9.200          High income
# 79      20.297  Lower middle income
# 80      20.291  Lower middle income
# 81      15.000          High income
# 82      17.900  Upper middle income
# 83      31.093  Upper middle income
# 84      13.400          High income
# 85      21.300          High income
# 86       8.500          High income
# 87      13.540  Upper middle income

# %%
Data
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
Data.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers', 'IncomeGroup']

# %%
Data
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
Data1 = Data.BirthRate * Data.InternetUsers

# %%
Data1
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
Data1 = Data.BirthRate / Data.InternetUsers

# %%
Data1
# Out:
# 0       0.129835
# 1       5.975085
# 2       2.407592
# 3       0.225122
# 4       0.125500
#          ...
# 190     1.647350
# 191     0.448387
# 192    19.270000
# 193     2.627987
# 194     1.930541
# Length: 195, dtype: float64

# %%
Data['Math'] = Data.BirthRate / Data.InternetUsers

# %%
Data
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup       Math
# 0            High income   0.129835
# 1             Low income   5.975085
# 2    Upper middle income   2.407592
# 3    Upper middle income   0.225122
# ...

# %%
Data.drop['Math', Axis=1]
# Out:
#   File "C:\Users\sammy\AppData\Local\Temp/ipykernel_16400/1517020940.py", line 1
#     Data.drop['Math', Axis=1]
#                           ^
# SyntaxError: invalid syntax

# %%
Data.drop('Math', 1)
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Filtering in DataFrames

# %%
Data.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup       Math
# 190  Lower middle income   1.647350
# 191  Upper middle income   0.448387
# 192           Low income  19.270000
# 193  Lower middle income   2.627987
# 194           Low income   1.930541

# %%
Data2 = Data.BirthRate > 20

# %%
Data2
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 190     True
# 191     True
# 192     True
# 193     True
# 194     True
# Name: BirthRate, Length: 195, dtype: bool

# %%
Data2 = Data.BirthRate is True

# %%
Data2
# Out:
# False

# %%
Data.drop('Math', 1)
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
Data[Data.InternetUsers > 20]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244           78.9
# 3                  Albania         ALB     12.877           57.2
# 4     United Arab Emirates         ARE     11.044           88.0
# 5                Argentina         ARG     17.716           59.9
# 6                  Armenia         ARM     13.308           41.9
# ..                     ...         ...        ...            ...
# 184          Venezuela, RB         VEN     19.842           54.9
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                Vietnam         VNM     15.537           43.9
# 188     West Bank and Gaza         PSE     30.394           46.6
# 191           South Africa         ZAF     20.850           46.5
#
#              IncomeGroup      Math
# 0            High income  0.129835
# 3    Upper middle income  0.225122
# 4            High income  0.125500
# 5            High income  0.295760
# ...

# %%
Data.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
Data3 = Data.IncomeGroup == 'High income'

# %%
Data3
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: IncomeGroup, Length: 195, dtype: bool

# %%
Data[Data3]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup  \
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
#          Math
# 0    0.129835
# ...

# %%
Data[Data.CountryName == 'Malta']
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup      Math
# 116       Malta         MLT        9.5        68.9138  High income  0.137853

# %%
Data.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup       Math
# 190  Lower middle income   1.647350
# 191  Upper middle income   0.448387
# 192           Low income  19.270000
# 193  Lower middle income   2.627987
# 194           Low income   1.930541

# %%
DataTail = Data.tail()

# %%
DataTail.iat[3,4]
# Out:
# 'Lower middle income'

# %%
Data.at[193, 'InternetUsers']
# Out:
# 15.4

# %%
Data.iat[193, 2]
# Out:
# 40.471

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sea
plt.rcParams['figure.figsize'] = 8,8
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
DataTail
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup       Math
# 190  Lower middle income   1.647350
# 191  Upper middle income   0.448387
# 192           Low income  19.270000
# 193  Lower middle income   2.627987
# 194           Low income   1.930541

# %%
G1 = sea.distplot(Data['BirthRate'])

# %%
Data
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup       Math
# 0            High income   0.129835
# 1             Low income   5.975085
# 2    Upper middle income   2.407592
# 3    Upper middle income   0.225122
# ...

# %%
G2 = sea.boxplot(data = Data, x="IncomeGroup", y="BirthRate")

# %%
Data.head(10)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup      Math
# 0          High income  0.129835
# 1           Low income  5.975085
# 2  Upper middle income  2.407592
# 3  Upper middle income  0.225122
# 4          High income  0.125500
# 5          High income  0.295760
# 6  Lower middle income  0.317613
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
#  5   Math           195 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 9.3+ KB

# %%
Data.dtypes
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# Math             float64
# dtype: object

# %%
G2
# Out:
# <AxesSubplot:xlabel='IncomeGroup', ylabel='BirthRate'>

# %%
G3 = sea.lmplot(data = Data, x="InternetUsers", y="BirthRate", fit_reg=False)

# %%
Data['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
Data
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup       Math
# 0            High income   0.129835
# 1             Low income   5.975085
# 2    Upper middle income   2.407592
# 3    Upper middle income   0.225122
# ...

# %%
G3 = sea.lmplot(data = Data, x="InternetUsers", y="BirthRate", fit_reg=False, hue='IncomeGroup', size=10, aspect=2)

# %% [markdown]
# ----

# %%
#Keyword arguements in python

# %%
G3 = sea.lmplot(data = Data, x="InternetUsers", y="BirthRate",        \
                fit_reg=False, hue='IncomeGroup', size=10, aspect=2,  \
               scatter_kws={'s':100})
